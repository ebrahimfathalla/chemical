# %% [markdown]
# # 0 Loading the Data

# %% [markdown]
# ## 0.1 Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 0.2 Reading the files

# %%
chemicals_df = pd.read_csv("cscpopendata.csv")

# %% [markdown]
# ## 0.3 Reading the data

# %%
chemicals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CSFId                   80662 non-null   float64
#  3   CSF                     80237 non-null   object
#  4   CompanyId               114635 non-null  int64
#  5   CompanyName             114635 non-null  object
#  6   BrandName               114408 non-null  object
#  7   PrimaryCategoryId       114635 non-null  int64
#  8   PrimaryCategory         114635 non-null  object
#  9   SubCategoryId           114635 non-null  int64
#  10  SubCategory             114635 non-null  object
#  11  CasId                   114635 non-null  int64
#  12  CasNumber               108159 non-null  object
#  13  ChemicalId              114635 non-null  int64
#  14  ChemicalName            114635 non-null  object
#  15  InitialDateReported     114635 non-null  object
#  16  MostRecentDateReported  114635 non-null  object
#  17  DiscontinuedDate        12920 non-null   object
#  18  ChemicalCreatedAt       114635 non-null  object
#  19  ChemicalUpdatedAt       114635 non-null  object
#  20  ChemicalDateRemoved     2985 non-null    object
#  21  ChemicalCount           114635 non-null  int64
# dtypes: float64(1), int64(7), object(14)
# memory usage: 19.2+ MB

# %%
chemicals_df.shape
# Out:
# (114635, 22)

# %%
print(chemicals_df["PrimaryCategory"].nunique())
print(chemicals_df["PrimaryCategory"].unique())
# Out:
# 13
# ['Makeup Products (non-permanent)' 'Hair Care Products (non-coloring)'
#  'Nail Products' 'Personal Care Products' 'Sun-Related Products'
#  'Bath Products' 'Skin Care Products ' 'Fragrances'
#  'Tattoos and Permanent Makeup' 'Hair Coloring Products'
#  'Oral Hygiene Products' 'Shaving Products' 'Baby Products']

# %%
chemicals_df
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 0            2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1            3                         Glover's Medicated Shampoo      NaN
# 2            3                         Glover's Medicated Shampoo      NaN
# 3            4           PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4            5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                                ...      ...
# 114630   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634   41524  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
#                  CSF  CompanyId                   CompanyName  BrandName  \
# 0                NaN          4                  New Avon LLC       AVON
# 1                NaN        338           J. Strickland & Co.   Glover's
# 2                NaN        338           J. Strickland & Co.   Glover's
# 3                NaN          4                  New Avon LLC       AVON
# 4                NaN          4                  New Avon LLC       AVON
# ...              ...        ...                           ...        ...
# 114630     Rosa Soft       1259               Yanbal USA, Inc     YANBAL
# 114631  Malva Spirit       1259               Yanbal USA, Inc     YANBAL
# 114632  Rojo Fashion       1259               Yanbal USA, Inc     YANBAL
# 114633  Terra Mystic       1259               Yanbal USA, Inc     YANBAL
# 114634           NaN         86  The Procter & Gamble Company  Old Spice
#
#         PrimaryCategoryId                    PrimaryCategory  SubCategoryId  \
# 0                      44    Makeup Products (non-permanent)             53
# 1                      18  Hair Care Products (non-coloring)             25
# 2                      18  Hair Care Products (non-coloring)             25
# 3                      44    Makeup Products (non-permanent)             46
# 4                      44    Makeup Products (non-permanent)             52
# ...                   ...                                ...            ...
# 114630                 44    Makeup Products (non-permanent)             53
# 114631                 44    Makeup Products (non-permanent)             53
# 114632                 44    Makeup Products (non-permanent)             53
# 114633                 44    Makeup Products (non-permanent)             53
# 114634                  6                      Bath Products            159
#
#         ...   CasNumber  ChemicalId            ChemicalName  \
# 0       ...  13463-67-7           6        Titanium dioxide
# 1       ...  65996-92-1           4  Distillates (coal tar)
# 2       ...    140-67-0           5               Estragole
# 3       ...  13463-67-7           7        Titanium dioxide
# 4       ...  13463-67-7           8        Titanium dioxide
# ...     ...         ...         ...                     ...
# 114630  ...  13463-67-7       68059        Titanium dioxide
# 114631  ...  13463-67-7       68060        Titanium dioxide
# 114632  ...  13463-67-7       68061        Titanium dioxide
# 114633  ...  13463-67-7       68062        Titanium dioxide
# 114634  ...  13463-67-7       68074        Titanium dioxide
#
#         InitialDateReported MostRecentDateReported DiscontinuedDate  \
# 0                06/17/2009             08/28/2013       02/01/2011
# 1                07/01/2009             07/01/2009              NaN
# 2                07/01/2009             07/01/2009              NaN
# 3                07/09/2009             08/28/2013              NaN
# 4                07/09/2009             08/28/2013       02/01/2011
# ...                     ...                    ...              ...
# 114630           06/19/2020             06/19/2020              NaN
# 114631           06/19/2020             06/19/2020              NaN
# 114632           06/19/2020             06/19/2020              NaN
# 114633           06/19/2020             06/19/2020              NaN
# 114634           06/23/2020             06/23/2020              NaN
#
#        ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 0             07/09/2009        07/09/2009                 NaN             1
# 1             07/01/2009        07/01/2009                 NaN             2
# 2             07/02/2009        07/02/2009                 NaN             2
# 3             07/09/2009        07/09/2009                 NaN             1
# 4             07/09/2009        07/09/2009                 NaN             1
# ...                  ...               ...                 ...           ...
# 114630        06/19/2020        06/19/2020                 NaN             1
# 114631        06/19/2020        06/19/2020                 NaN             1
# 114632        06/19/2020        06/19/2020                 NaN             1
# 114633        06/19/2020        06/19/2020                 NaN             1
# 114634        06/23/2020        06/23/2020                 NaN             1
#
# [114635 rows x 22 columns]

# %% [markdown]
# # 1.0 Cleaning the data

# %%
newc_df=chemicals_df.drop(columns=["CSFId","CSF"]).copy()

# %%
newc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CompanyId               114635 non-null  int64
#  3   CompanyName             114635 non-null  object
#  4   BrandName               114408 non-null  object
#  5   PrimaryCategoryId       114635 non-null  int64
#  6   PrimaryCategory         114635 non-null  object
#  7   SubCategoryId           114635 non-null  int64
#  8   SubCategory             114635 non-null  object
#  9   CasId                   114635 non-null  int64
#  10  CasNumber               108159 non-null  object
#  11  ChemicalId              114635 non-null  int64
#  12  ChemicalName            114635 non-null  object
#  13  InitialDateReported     114635 non-null  object
#  14  MostRecentDateReported  114635 non-null  object
#  15  DiscontinuedDate        12920 non-null   object
#  16  ChemicalCreatedAt       114635 non-null  object
#  17  ChemicalUpdatedAt       114635 non-null  object
#  18  ChemicalDateRemoved     2985 non-null    object
#  19  ChemicalCount           114635 non-null  int64
# dtypes: int64(7), object(13)
# memory usage: 17.5+ MB

# %%
cols2see=["DiscontinuedDate","CDPHId","PrimaryCategory"]

newc_df[cols2see].groupby("PrimaryCategory").count()
# Out:
#                                    DiscontinuedDate  CDPHId
# PrimaryCategory
# Baby Products                                    11      49
# Bath Products                                   556    3466
# Fragrances                                      125     654
# Hair Care Products (non-coloring)               341    1620
# Hair Coloring Products                          431    2061
# Makeup Products (non-permanent)                8367   75827
# Nail Products                                   764   15347
# Oral Hygiene Products                            27     525
# Personal Care Products                          263     765
# Shaving Products                                 33     222
# Skin Care Products                             1148    7683
# Sun-Related Products                            853    4939
# Tattoos and Permanent Makeup                      1    1477

# %%
cols2see=["DiscontinuedDate","CDPHId","CompanyId"]

newc_df[cols2see].groupby("CompanyId").count()
# Out:
#            DiscontinuedDate  CDPHId
# CompanyId
# 4                       363     762
# 11                       13     252
# 12                        0       7
# 18                        0     168
# 20                        0       5
# ...                     ...     ...
# 1377                      0     196
# 1379                      0      26
# 1388                      0      13
# 1390                      0       4
# 1391                      0       1
#
# [635 rows x 2 columns]

# %%
chemicals_df[~chemicals_df['DiscontinuedDate'].isna()].sample(20)
# Out:
#        CDPHId                                        ProductName    CSFId  \
# 41393   14604                          EYE AND LIP CONTOUR CREAM      NaN
# 71985   26232    CoverGirl Advanced Radiance Make-Up + Sunscreen  39577.0
# 76090   27386             CoverGirl Queen Stay Luscious Lipstick  42288.0
# 76540   27599  Wella Professionals Color Touch Special Mix De...  42551.0
# 60100   21955        CoverGirl Outlast Stay Brilliant Nail Gloss  42417.0
# 42838   15090   Virtually Weightless Colour-adjusting Foundation  21121.0
# 35725   12266                                  Diamond Lip Gloss  17716.0
# 25271    7088                                        Eye contour      NaN
# 36309   12648                        VS Home Collection Bar Soap  23359.0
# 71973   26231                 CoverGirl Simply Powder Foundation  39567.0
# 53775   19258                                  Powder Foundation  28696.0
# 71373   26015                        Nail Polish (Platinum Star)      NaN
# 77546   27960  TERRACOTTA - TERRA MAGNIFICA - BRONZING POWDER...      NaN
# 54917   19648               Very Sexy Make Up Light Up Lip Gloss  29670.0
# 11137    2815                                 Mango Foaming Bath      NaN
# 55866   20178                  CoverGirl Jumbo Gloss Balm Sheers  29941.0
# 90130   33077  Too Faced Peach Kiss Moisture Matte Long Wear ...  49447.0
# 73320   26533               CoverGirl Queen Vibrant Hue Lipstick  40436.0
# 71247   25956                    Lip Gloss (Passion Fruit Punch)      NaN
# 15104    3497  Nature's Gate Organics Advanced Care Oh What A...      NaN
#
#                         CSF  CompanyId                       CompanyName  \
# 41393                   NaN        127            Shiseido America, Inc.
# 71985         Classic Ivory         86      The Procter & Gamble Company
# 76090               Passion         86      The Procter & Gamble Company
# 76540   0/45 Red Red-Violet         86      The Procter & Gamble Company
# 60100             Rose Gold         86      The Procter & Gamble Company
# 42838            Shade Dark        562             The Boots Company PLC
# 35725              Princess        556          Victoria's Secret Beauty
# 25271                   NaN        301                  Yves Rocher Inc.
# 36309        Winter Chateau        556          Victoria's Secret Beauty
# 71973          Medium Light         86      The Procter & Gamble Company
# 53775                    44        864  Nippon Menard Cosmetic Co., Ltd.
# 71373                   NaN       1000                         MAESA LLC
# 77546                   NaN        298                          GUERLAIN
# 54917                  Buzz        556          Victoria's Secret Beauty
# 11137                   NaN         77             Buth-na-Bodhaige, Inc
# 55866  Frosted Cherry Twist         86      The Procter & Gamble Company
# 90130              CI 15985       1213               Too Faced Cosmetics
# 73320           Cherry Bomb         86      The Procter & Gamble Company
# 71247                   NaN       1000                         MAESA LLC
# 15104                   NaN       1232                        LEVLAD LLC
#
#                       BrandName  PrimaryCategoryId  \
# 41393  SHISEIDO FUTURE SOLUTION                 90
# 71985                 CoverGirl                106
# 76090                 CoverGirl                 44
# 76540                     Wella                 32
# 60100                 CoverGirl                 59
# 42838            Boots Botanics                 44
# 35725  Victoria's Secret Beauty                 44
# 25271                      Yria                 44
# 36309  Victoria's Secret Beauty                 90
# 71973                 CoverGirl                 44
# 53775                    Jupier                 44
# 71373                     Bongo                 59
# 77546                  GUERLAIN                 44
# 54917  Victoria's Secret Beauty                 44
# 11137             The Body Shop                  6
# 55866                 CoverGirl                 44
# 90130       Too Faced Cosmetics                 44
# 73320                 CoverGirl                 44
# 71247                     Bongo                 44
# 15104             Nature's Gate                 90
#
#                        PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 41393              Skin Care Products              92  ...  13463-67-7
# 71985             Sun-Related Products            107  ...  13463-67-7
# 76090  Makeup Products (non-permanent)             53  ...  13463-67-7
# 76540           Hair Coloring Products             35  ...  13463-67-7
# 60100                    Nail Products             65  ...  13463-67-7
# 42838  Makeup Products (non-permanent)             50  ...  13463-67-7
# 35725  Makeup Products (non-permanent)             52  ...  13463-67-7
# 25271  Makeup Products (non-permanent)             46  ...  13463-67-7
# 36309              Skin Care Products              93  ...         NaN
# 71973  Makeup Products (non-permanent)             50  ...  13463-67-7
# 53775  Makeup Products (non-permanent)             50  ...  13463-67-7
# 71373                    Nail Products             65  ...  12001-26-2
# 77546  Makeup Products (non-permanent)             49  ...  13463-67-7
# 54917  Makeup Products (non-permanent)             52  ...         NaN
# 11137                    Bath Products              9  ...  68603-42-9
# 55866  Makeup Products (non-permanent)             52  ...  13463-67-7
# 90130  Makeup Products (non-permanent)             53  ...  13463-67-7
# 73320  Makeup Products (non-permanent)             53  ...  13463-67-7
# 71247  Makeup Products (non-permanent)             52  ...  12001-26-2
# 15104              Skin Care Products              97  ...  13463-67-7
#
#        ChemicalId                                       ChemicalName  \
# 41393       22361                                   Titanium dioxide
# 71985       41287                                   Titanium dioxide
# 76090       44351                                   Titanium dioxide
# 76540       44780                                   Titanium dioxide
# 60100       44465                                   Titanium dioxide
# 42838       23123                                   Titanium dioxide
# 35725       18468                                   Titanium dioxide
# 25271       11103                                   Titanium dioxide
# 36309       19350  Retinol/retinyl esters, when in daily dosages ...
# 71973       41277                                   Titanium dioxide
# 53775       29276                                   Titanium dioxide
# 71373       40743                                               Mica
# 77546       45333                                   Titanium dioxide
# 54917       29893  Retinol/retinyl esters, when in daily dosages ...
# 11137        4496                            Cocamide diethanolamine
# 55866       30643                                   Titanium dioxide
# 90130       53379                                   Titanium dioxide
# 73320       41980                                   Titanium dioxide
# 71247       40618                                               Mica
# 15104        6207                                   Titanium dioxide
#
#        InitialDateReported MostRecentDateReported DiscontinuedDate  \
# 41393           07/07/2010             09/10/2014       01/01/2014
# 71985           05/13/2015             10/12/2018       10/02/2016
# 76090           12/15/2015             10/11/2018       10/02/2016
# 76540           01/27/2016             10/19/2018       10/02/2016
# 60100           01/02/2014             10/11/2018       10/02/2016
# 42838           08/19/2010             10/16/2013       10/16/2013
# 35725           06/11/2010             12/06/2013       04/01/2007
# 25271           11/19/2009             11/08/2013       11/22/2010
# 36309           06/17/2010             12/09/2013       03/01/2009
# 71973           05/12/2015             05/12/2015       07/01/2013
# 53775           01/08/2013             05/27/2015       09/23/2014
# 71373           04/08/2015             10/30/2015       04/08/2015
# 77546           03/17/2016             06/13/2018       12/31/2016
# 54917           02/28/2013             12/16/2013       04/01/2011
# 11137           10/08/2009             02/11/2011       02/11/2011
# 55866           07/10/2013             10/11/2018       10/02/2016
# 90130           05/17/2018             05/17/2018       12/01/2017
# 73320           07/20/2015             07/20/2015       01/01/2011
# 71247           04/03/2015             10/30/2015       04/03/2015
# 15104           10/12/2009             08/15/2019       10/14/2016
#
#       ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 41393        07/07/2010        08/04/2014                 NaN             1
# 71985        05/13/2015        05/13/2015                 NaN             1
# 76090        12/15/2015        12/15/2015                 NaN             1
# 76540        01/27/2016        01/27/2016                 NaN             1
# 60100        01/07/2016        01/07/2016                 NaN             1
# 42838        08/19/2010        08/19/2010                 NaN             1
# 35725        06/11/2010        12/06/2013                 NaN             1
# 25271        11/19/2009        11/19/2009                 NaN             1
# 36309        06/17/2010        12/09/2013                 NaN             1
# 71973        05/12/2015        05/12/2015                 NaN             1
# 53775        01/08/2013        01/08/2013                 NaN             1
# 71373        04/08/2015        04/08/2015                 NaN             4
# 77546        03/17/2016        03/17/2016                 NaN             1
# 54917        02/28/2013        12/16/2013                 NaN             2
# 11137        10/08/2009        02/21/2014          02/11/2011             0
# 55866        07/11/2013        07/11/2013                 NaN             1
# 90130        05/17/2018        05/17/2018                 NaN             1
# 73320        07/20/2015        07/20/2015                 NaN             1
# 71247        04/03/2015        04/03/2015                 NaN             3
# 15104        10/12/2009        10/12/2009                 NaN             1
#
# [20 rows x 22 columns]

# %%
newc_df[newc_df['ChemicalCreatedAt'] != newc_df['ChemicalUpdatedAt']]
# Out:
#         CDPHId                                        ProductName  CompanyId  \
# 31          24                          White Premium Lotion Soap        181
# 224         71  Colorstay 12 Hour Eye Shadow Quad- rose shimme...         23
# 308        156                                  A&C synergy serum         55
# 311        156                                  A&C synergy serum         55
# 431        269     Elizabeth Arden Green Tea Relaxing Bubble Bath         69
# ...        ...                                                ...        ...
# 114325   41419             SEPHORA - WILD WISHES - MAKEUP PALETTE        198
# 114329   41419             SEPHORA - WILD WISHES - MAKEUP PALETTE        198
# 114333   41419             SEPHORA - WILD WISHES - MAKEUP PALETTE        198
# 114337   41419             SEPHORA - WILD WISHES - MAKEUP PALETTE        198
# 114341   41419             SEPHORA - WILD WISHES - MAKEUP PALETTE        198
#
#                                 CompanyName        BrandName  \
# 31                    GOJO Industries, Inc.            GOJO�
# 224     Revlon Consumer Product Corporation           Revlon
# 308          Physician's Care Alliance, LLC         PCA Skin
# 311          Physician's Care Alliance, LLC         PCA Skin
# 431                   Elizabeth Arden, Inc.  Elizabeth Arden
# ...                                     ...              ...
# 114325                                   S+          SEPHORA
# 114329                                   S+          SEPHORA
# 114333                                   S+          SEPHORA
# 114337                                   S+          SEPHORA
# 114341                                   S+          SEPHORA
#
#         PrimaryCategoryId                  PrimaryCategory  SubCategoryId  \
# 31                     74           Personal Care Products            170
# 224                    44  Makeup Products (non-permanent)             48
# 308                    90              Skin Care Products              99
# 311                    90              Skin Care Products             100
# 431                     6                    Bath Products              9
# ...                   ...                              ...            ...
# 114325                 44  Makeup Products (non-permanent)             45
# 114329                 44  Makeup Products (non-permanent)             46
# 114333                 44  Makeup Products (non-permanent)             48
# 114337                 44  Makeup Products (non-permanent)             49
# 114341                 44  Makeup Products (non-permanent)             52
#
#                                       SubCategory  CasId   CasNumber  \
# 31                  Hand Cleansers and Sanitizers    162  68603-42-9
# 224                                    Eye Shadow    656  13463-67-7
# 308     Skin Astringent (making a cosmetic claim)    958     68-26-8
# 311     Skin Bleaching (making a cosmetic claim)     958     68-26-8
# 431                 Bubble and Foam Bath Products    656  13463-67-7
# ...                                           ...    ...         ...
# 114325                                   Blushes     656  13463-67-7
# 114329                   Eyeliner/Eyebrow Pencils    656  13463-67-7
# 114333                                 Eye Shadow    656  13463-67-7
# 114337                               Face Powders    656  13463-67-7
# 114341                            Lip Gloss/Shine    656  13463-67-7
#
#         ChemicalId             ChemicalName InitialDateReported  \
# 31              26  Cocamide diethanolamine          2009-07-23
# 224             78         Titanium dioxide          2009-08-26
# 308           2080                  Retinol          2009-08-28
# 311           2080                  Retinol          2009-08-28
# 431            281         Titanium dioxide          2009-09-01
# ...            ...                      ...                 ...
# 114325       67830         Titanium dioxide          2020-04-22
# 114329       67830         Titanium dioxide          2020-04-22
# 114333       67830         Titanium dioxide          2020-04-22
# 114337       67830         Titanium dioxide          2020-04-22
# 114341       67830         Titanium dioxide          2020-04-22
#
#        MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 31                 2012-02-07              NaT        2009-07-23
# 224                2009-08-26              NaT        2009-08-26
# 308                2018-01-24              NaT        2009-09-29
# 311                2018-01-24              NaT        2009-09-29
# 431                2017-01-12       2013-05-13        2009-09-01
# ...                       ...              ...               ...
# 114325             2020-04-24              NaT        2020-04-22
# 114329             2020-04-24              NaT        2020-04-22
# 114333             2020-04-24              NaT        2020-04-22
# 114337             2020-04-24              NaT        2020-04-22
# 114341             2020-04-24              NaT        2020-04-22
#
#        ChemicalUpdatedAt ChemicalDateRemoved  ChemicalCount
# 31            2012-02-07          2010-12-30              0
# 224           2009-09-14          2009-09-14              1
# 308           2012-07-03                 NaT              3
# 311           2012-07-03                 NaT              3
# 431           2009-09-25          2009-09-25              1
# ...                  ...                 ...            ...
# 114325        2020-04-24                 NaT              3
# 114329        2020-04-24                 NaT              3
# 114333        2020-04-24                 NaT              3
# 114337        2020-04-24                 NaT              3
# 114341        2020-04-24                 NaT              3
#
# [9564 rows x 20 columns]

# %% [markdown]
# ### 1.1 Changing dates types to "datetime"

# %%
date_cols=["InitialDateReported","MostRecentDateReported","DiscontinuedDate","ChemicalCreatedAt","ChemicalUpdatedAt","ChemicalDateRemoved"]

newc_df[date_cols] = newc_df[date_cols].apply(pd.to_datetime)

# %%
newc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CompanyId               114635 non-null  int64
#  3   CompanyName             114635 non-null  object
#  4   BrandName               114635 non-null  object
#  5   PrimaryCategoryId       114635 non-null  int64
#  6   PrimaryCategory         114635 non-null  object
#  7   SubCategoryId           114635 non-null  int64
#  8   SubCategory             114635 non-null  object
#  9   CasId                   114635 non-null  int64
#  10  CasNumber               108159 non-null  object
#  11  ChemicalId              114635 non-null  int64
#  12  ChemicalName            114635 non-null  object
#  13  InitialDateReported     114635 non-null  datetime64[ns]
#  14  MostRecentDateReported  114635 non-null  datetime64[ns]
#  15  DiscontinuedDate        12920 non-null   datetime64[ns]
#  16  ChemicalCreatedAt       114635 non-null  datetime64[ns]
#  17  ChemicalUpdatedAt       114635 non-null  datetime64[ns]
#  18  ChemicalDateRemoved     2985 non-null    datetime64[ns]
#  19  ChemicalCount           114635 non-null  int64
# dtypes: datetime64[ns](6), int64(7), object(7)
# memory usage: 17.5+ MB

# %% [markdown]
# ### 1.2 Filling the rows where the Brand name is missing from the company name column:

# %%
known_brands = newc_df["BrandName"].dropna().unique()
def extract_brand(CompanyName, known_brands):
    if pd.isna(CompanyName):
        return None
    for brand in known_brands:
        if isinstance(CompanyName, str) and brand.lower() in CompanyName.lower():
            return brand
    return None
for i in range(len(newc_df)):
    if pd.isna(newc_df.loc[i, "BrandName"]):
        company = newc_df.loc[i, "CompanyName"]
        guessed_brand = extract_brand(company, known_brands)
        if guessed_brand:
            newc_df.loc[i, "BrandName"] = guessed_brand

# %% [markdown]
# #### 1.2.1 Now we dont have any missing values in the "BrandName" column:

# %%
newc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CompanyId               114635 non-null  int64
#  3   CompanyName             114635 non-null  object
#  4   BrandName               114635 non-null  object
#  5   PrimaryCategoryId       114635 non-null  int64
#  6   PrimaryCategory         114635 non-null  object
#  7   SubCategoryId           114635 non-null  int64
#  8   SubCategory             114635 non-null  object
#  9   CasId                   114635 non-null  int64
#  10  CasNumber               108159 non-null  object
#  11  ChemicalId              114635 non-null  int64
#  12  ChemicalName            114635 non-null  object
#  13  InitialDateReported     114635 non-null  datetime64[ns]
#  14  MostRecentDateReported  114635 non-null  datetime64[ns]
#  15  DiscontinuedDate        12920 non-null   datetime64[ns]
#  16  ChemicalCreatedAt       114635 non-null  datetime64[ns]
#  17  ChemicalUpdatedAt       114635 non-null  datetime64[ns]
#  18  ChemicalDateRemoved     2985 non-null    datetime64[ns]
#  19  ChemicalCount           114635 non-null  int64
# dtypes: datetime64[ns](6), int64(7), object(7)
# memory usage: 17.5+ MB

# %%
# name_to_id = {}
# for i in range(len(newc_df)):
#     chem_id = newc_df.loc[i, "ChemicalID"]
#     chem_name = newc_df.loc[i, "ChemicalName"]
#     if pd.notna(chem_id):  # if ChemicalID exists
#         name_to_id[chem_name] = chem_id  # save in dictionary

# # Step 2: Fill missing ChemicalID using the dictionary
# for i in range(len(newc_df)):
#     if pd.isna(newc_df.loc[i, "ChemicalID"]):  # if missing ChemicalID
#         chem_name = newc_df.loc[i, "ChemicalName"]
#         if chem_name in name_to_id:  # if chemical name found in dictionary
#             newc_df.loc[i, "ChemicalID"] = name_to_id[chem_name]  # fill missing ID

# %%
topcompanies = newc_df["CompanyName"].value_counts().head(5)
botcompanies= newc_df["CompanyName"].value_counts().tail(5)
print(topcompanies)
print(botcopmaines)
# Out:
# CompanyName
# L'Oreal USA                            5747
# S+                                     5165
# Coty                                   5162
# Revlon Consumer Product Corporation    4341
# Bare Escentuals Beauty, Inc.           3828
# Name: count, dtype: int64
# CompanyName
# Hada S.A.                              1
# LES SALONS DU PALAIS ROYAL SHISEIDO    1
# Tupperware U.S., Inc.                  1
# OSEA Malibu                            1
# Turquise Global LLC                    1
# Name: count, dtype: int64

# %%
topchemicals = newc_df["ChemicalName"].value_counts().head(5)
print(topchemicals)
# Out:
# ChemicalName
# Titanium dioxide                                                                                       93480
# Silica, crystalline (airborne particles of respirable size)                                             2817
# Retinol/retinyl esters, when in daily dosages in excess of 10,000 IU, or 3,000 retinol equivalents.     2154
# Mica                                                                                                    1919
# Butylated hydroxyanisole                                                                                1888
# Name: count, dtype: int64

# %%
newc_df.head(10)
# Out:
#    CDPHId                                        ProductName  CompanyId  \
# 0       2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES          4
# 1       3                         Glover's Medicated Shampoo        338
# 2       3                         Glover's Medicated Shampoo        338
# 3       4           PRECISION GLIMMER EYE LINER-ALL SHADES �          4
# 4       5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �          4
# 5       6  JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...          4
# 6       7  ABSOLUTE Precision Color Powder System - All S...         11
# 7       7  ABSOLUTE Precision Color Powder System - All S...         11
# 8       7  ABSOLUTE Precision Color Powder System - All S...         11
# 9       8  ABSOLUTE Precision Color Powder System Opaque ...         11
#
#            CompanyName BrandName  PrimaryCategoryId  \
# 0         New Avon LLC      AVON                 44
# 1  J. Strickland & Co.  Glover's                 18
# 2  J. Strickland & Co.  Glover's                 18
# 3         New Avon LLC      AVON                 44
# 4         New Avon LLC      AVON                 44
# 5         New Avon LLC      AVON                 44
# 6    OPI PRODUCTS INC.       OPI                 59
# 7    OPI PRODUCTS INC.       OPI                 59
# 8    OPI PRODUCTS INC.       OPI                 59
# 9    OPI PRODUCTS INC.  ABSOLUTE                 59
#
#                      PrimaryCategory  SubCategoryId  \
# 0    Makeup Products (non-permanent)             53
# 1  Hair Care Products (non-coloring)             25
# 2  Hair Care Products (non-coloring)             25
# 3    Makeup Products (non-permanent)             46
# 4    Makeup Products (non-permanent)             52
# 5    Makeup Products (non-permanent)             48
# 6                      Nail Products             60
# 7                      Nail Products             60
# 8                      Nail Products             60
# 9                      Nail Products             60
#
#                                   SubCategory   CasNumber  \
# 0  Lip Color - Lipsticks, Liners, and Pencils  13463-67-7
# 1    Hair Shampoos (making a cosmetic claim)   65996-92-1
# 2    Hair Shampoos (making a cosmetic claim)     140-67-0
# 3                    Eyeliner/Eyebrow Pencils  13463-67-7
# 4                             Lip Gloss/Shine  13463-67-7
# 5                                  Eye Shadow  13463-67-7
# 6       Artificial Nails and Related Products  13463-67-7
# 7       Artificial Nails and Related Products  13463-67-7
# 8       Artificial Nails and Related Products  13463-67-7
# 9       Artificial Nails and Related Products  13463-67-7
#
#              ChemicalName InitialDateReported MostRecentDateReported  \
# 0        Titanium dioxide          2009-06-17             2013-08-28
# 1  Distillates (coal tar)          2009-07-01             2009-07-01
# 2               Estragole          2009-07-01             2009-07-01
# 3        Titanium dioxide          2009-07-09             2013-08-28
# 4        Titanium dioxide          2009-07-09             2013-08-28
# 5        Titanium dioxide          2009-07-09             2013-08-28
# 6        Titanium dioxide          2009-07-13             2010-12-30
# 7        Titanium dioxide          2009-07-13             2010-12-30
# 8        Titanium dioxide          2009-07-13             2010-12-30
# 9        Titanium dioxide          2009-07-13             2010-12-30
#
#   DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved  \
# 0       2011-02-01        2009-07-09        2009-07-09                 NaT
# 1              NaT        2009-07-01        2009-07-01                 NaT
# 2              NaT        2009-07-02        2009-07-02                 NaT
# 3              NaT        2009-07-09        2009-07-09                 NaT
# 4       2011-02-01        2009-07-09        2009-07-09                 NaT
# 5       2010-11-01        2009-07-09        2009-07-09                 NaT
# 6              NaT        2009-12-04        2009-12-04                 NaT
# 7              NaT        2009-12-04        2009-12-04                 NaT
# 8              NaT        2009-12-04        2009-12-04                 NaT
# 9              NaT        2010-06-09        2010-06-09                 NaT
#
#    ChemicalCount
# 0              1
# 1              2
# 2              2
# 3              1
# 4              1
# 5              1
# 6              1
# 7              1
# 8              1
# 9              1

# %% [markdown]
# ### 1.3 Since Cas Number is the gold standard to identify chemicals we will be dropping the other ID's

# %%
newc_df.drop(['CasId','ChemicalId'], axis=1, inplace=True)

# %%
newc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CompanyId               114635 non-null  int64
#  3   CompanyName             114635 non-null  object
#  4   BrandName               114635 non-null  object
#  5   PrimaryCategoryId       114635 non-null  int64
#  6   PrimaryCategory         114635 non-null  object
#  7   SubCategoryId           114635 non-null  int64
#  8   SubCategory             114635 non-null  object
#  9   CasNumber               108159 non-null  object
#  10  ChemicalName            114635 non-null  object
#  11  InitialDateReported     114635 non-null  datetime64[ns]
#  12  MostRecentDateReported  114635 non-null  datetime64[ns]
#  13  DiscontinuedDate        12920 non-null   datetime64[ns]
#  14  ChemicalCreatedAt       114635 non-null  datetime64[ns]
#  15  ChemicalUpdatedAt       114635 non-null  datetime64[ns]
#  16  ChemicalDateRemoved     2985 non-null    datetime64[ns]
#  17  ChemicalCount           114635 non-null  int64
# dtypes: datetime64[ns](6), int64(5), object(7)
# memory usage: 15.7+ MB

# %% [markdown]
# ### 1.4 Filling the CasId Nulls using a dictionary

# %%
cas_lookup = (
    newc_df[newc_df['CasNumber'].notnull()]
    .drop_duplicates(subset='ChemicalName')
    .set_index('ChemicalName')['CasNumber']
    .to_dict()
)

newc_df['CasNumber'] = newc_df['CasNumber'].fillna(newc_df['ChemicalName'].map(cas_lookup))

# %%
newc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CompanyId               114635 non-null  int64
#  3   CompanyName             114635 non-null  object
#  4   BrandName               114635 non-null  object
#  5   PrimaryCategoryId       114635 non-null  int64
#  6   PrimaryCategory         114635 non-null  object
#  7   SubCategoryId           114635 non-null  int64
#  8   SubCategory             114635 non-null  object
#  9   CasNumber               110886 non-null  object
#  10  ChemicalName            114635 non-null  object
#  11  InitialDateReported     114635 non-null  datetime64[ns]
#  12  MostRecentDateReported  114635 non-null  datetime64[ns]
#  13  DiscontinuedDate        12920 non-null   datetime64[ns]
#  14  ChemicalCreatedAt       114635 non-null  datetime64[ns]
#  15  ChemicalUpdatedAt       114635 non-null  datetime64[ns]
#  16  ChemicalDateRemoved     2985 non-null    datetime64[ns]
#  17  ChemicalCount           114635 non-null  int64
# dtypes: datetime64[ns](6), int64(5), object(7)
# memory usage: 15.7+ MB

# %% [markdown]
# ### 1.5 The chemicals where the cas number is missing:

# %%
missingcas=newc_df[newc_df['CasNumber'].isna()]
counts = missingcas['ChemicalName'].value_counts()
print(counts)
# Out:
# ChemicalName
# Silica, crystalline (airborne particles of respirable size)          2817
# Cocamide DEA                                                          234
# Cosmetic talc                                                         189
# Aloe vera, whole leaf extract                                         143
# Titanium dioxide (airborne, unbound particles of respirable size)      84
# Coffee                                                                 80
# Isopropyl alcohol manufacture using strong acids                       75
# Coal tars                                                              39
# Coffee extract                                                         13
# 2,4-Hexadienal (89% trans, trans isomer; 11% cis, trans isomer)         9
# Arsenic (inorganic arsenic compounds)                                   9
# Talc (powder)                                                           9
# Carbon-black extracts                                                   8
# Talc containing asbestiform fibers                                      8
# Coffee bean extract                                                     6
# Formaldehyde solution                                                   5
# Aloe vera, non-decolorized whole leaf extract                           4
# Chromium (hexavalent compounds)                                         3
# Coal tar solution                                                       3
# Goldenseal root powder                                                  2
# Hydrous magnesium silicate                                              2
# Retinol palmitate                                                       1
# Extract of coffee bean                                                  1
# Cocamide diethanolamine (DEA)                                           1
# 2-Propyleneacrolein                                                     1
# Arsenic (inorganic oxides)                                              1
# Cocamide                                                                1
# Diethanolamides of the fatty acids of coconut oil                       1
# Name: count, dtype: int64

# %%
newc_df.head()
# Out:
#    CDPHId                                       ProductName  CompanyId  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES          4
# 1       3                        Glover's Medicated Shampoo        338
# 2       3                        Glover's Medicated Shampoo        338
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �          4
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �          4
#
#            CompanyName BrandName  PrimaryCategoryId  \
# 0         New Avon LLC      AVON                 44
# 1  J. Strickland & Co.  Glover's                 18
# 2  J. Strickland & Co.  Glover's                 18
# 3         New Avon LLC      AVON                 44
# 4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  \
# 0    Makeup Products (non-permanent)             53
# 1  Hair Care Products (non-coloring)             25
# 2  Hair Care Products (non-coloring)             25
# 3    Makeup Products (non-permanent)             46
# 4    Makeup Products (non-permanent)             52
#
#                                   SubCategory   CasNumber  \
# 0  Lip Color - Lipsticks, Liners, and Pencils  13463-67-7
# 1    Hair Shampoos (making a cosmetic claim)   65996-92-1
# 2    Hair Shampoos (making a cosmetic claim)     140-67-0
# 3                    Eyeliner/Eyebrow Pencils  13463-67-7
# 4                             Lip Gloss/Shine  13463-67-7
#
#              ChemicalName InitialDateReported MostRecentDateReported  \
# 0        Titanium dioxide          2009-06-17             2013-08-28
# 1  Distillates (coal tar)          2009-07-01             2009-07-01
# 2               Estragole          2009-07-01             2009-07-01
# 3        Titanium dioxide          2009-07-09             2013-08-28
# 4        Titanium dioxide          2009-07-09             2013-08-28
#
#   DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved  \
# 0       2011-02-01        2009-07-09        2009-07-09                 NaT
# 1              NaT        2009-07-01        2009-07-01                 NaT
# 2              NaT        2009-07-02        2009-07-02                 NaT
# 3              NaT        2009-07-09        2009-07-09                 NaT
# 4       2011-02-01        2009-07-09        2009-07-09                 NaT
#
#    ChemicalCount
# 0              1
# 1              2
# 2              2
# 3              1
# 4              1

# %% [markdown]
# # 2.0 Starting The Analysis

# %% [markdown]
# ## 2.1 Number of products that has been reported after discountinuation:

# %%
repafterdisc = (
    (newc_df['DiscontinuedDate'].notna()) & 
    (
        (newc_df['InitialDateReported'] > newc_df['DiscontinuedDate']) |
        (newc_df['MostRecentDateReported'] > newc_df['DiscontinuedDate'])
    )
).sum()

print("Number of chemicals reported after discontinuation:", repafterdisc)
# Out:
# Number of chemicals reported after discontinuation: 11516

# %% [markdown]
# ## 2.2 Number of Products that has been updated after last report:

# %%
upafterrep = (
    (newc_df['ChemicalUpdatedAt'] > newc_df['MostRecentDateReported']) |
    (newc_df['ChemicalUpdatedAt'] > newc_df['InitialDateReported'])
).sum()

print("Number of chemicals updated after being reported (initial or most recent):", upafterrep)
# Out:
# Number of chemicals updated after being reported (initial or most recent): 18086

# %% [markdown]
# ## 2.3 Which subcategories have the highest number of reported chemicals?

# %%
subcategory_counts = newc_df['SubCategory'].value_counts().head(10)
print("Top 10 subcategories by chemical count:")
print(subcategory_counts)
# Out:
# Top 10 subcategories by chemical count:
# SubCategory
# Lip Color - Lipsticks, Liners, and Pencils     16555
# Eye Shadow                                     15744
# Foundations and Bases                          14096
# Nail Polish and Enamel                          9945
# Lip Gloss/Shine                                 8972
# Eyeliner/Eyebrow Pencils                        5948
# Face Powders                                    4928
# Sunscreen (making a cosmetic claim)             4557
# Blushes                                         4082
# Skin Moisturizers (making a cosmetic claim)     3365
# Name: count, dtype: int64

# %% [markdown]
# ## 2.4 What are the top 5 companies with the most reported products?

# %%
top_companies = newc_df['CompanyName'].value_counts().head(5)
print("Top 5 companies by number of products reported:")
print(top_companies)
# Out:
# Top 5 companies by number of products reported:
# CompanyName
# L'Oreal USA                            5747
# S+                                     5165
# Coty                                   5162
# Revlon Consumer Product Corporation    4341
# Bare Escentuals Beauty, Inc.           3828
# Name: count, dtype: int64

# %%
bot_companies = newc_df['CompanyName'].value_counts().tail(5)
print("Bot 5 companies by number of products reported:")
print(bot_companies)
# Out:
# Bot 5 companies by number of products reported:
# CompanyName
# Hada S.A.                              1
# LES SALONS DU PALAIS ROYAL SHISEIDO    1
# Tupperware U.S., Inc.                  1
# OSEA Malibu                            1
# Turquise Global LLC                    1
# Name: count, dtype: int64

# %% [markdown]
# ## 2.5 What percentage of chemicals were ever discontinued?

# %%
discontinued_percent = (newc_df['DiscontinuedDate'].notna().sum() / len(newc_df)) * 100
print(f"Percentage of discontinued chemicals: {discontinued_percent:.2f}%")
# Out:
# Percentage of discontinued chemicals: 11.27%

# %% [markdown]
# ## 2.6 What is the average time (in days) between chemical creation and most recent report?

# %%
time_diff = (newc_df['MostRecentDateReported'] - newc_df['ChemicalCreatedAt']).dt.days
average_days = time_diff.mean()
print(f"Average days from creation to most recent report: {average_days:.1f} days")
# Out:
# Average days from creation to most recent report: 488.8 days

# %% [markdown]
# ## 2.7 Which categories or companies are more prone to missing CAS data?

# %%
missing_cas_by_cat = newc_df[newc_df['CasNumber'].isna()]['PrimaryCategory'].value_counts().head(3)
missing_cas_by_cat.sort_values(ascending=True).plot(kind='barh', title='Top Categories with Missing CAS Numbers')
plt.xlabel('Count of Missing CAS Numbers')
plt.show()

# %% [markdown]
# ## 2.8 Reporting vs Discontinuation ?

# %%
mask = newc_df['DiscontinuedDate'].notna()
late_reports = newc_df[mask & (newc_df['MostRecentDateReported'] > newc_df['DiscontinuedDate'])]
delay_days = (late_reports['MostRecentDateReported'] - late_reports['DiscontinuedDate']).dt.days

delay_days.hist(bins=30)
plt.title('Days Reported After Discontinuation')
plt.xlabel('Days')
plt.ylabel('Number of Chemicals')
plt.show()

# %% [markdown]
# ## 2.9 Chemicals Reported per year

# %%
newc_df['YearReported'] = newc_df['InitialDateReported'].dt.year
newc_df['YearReported'].value_counts().sort_index().plot(kind='line', marker='o')
plt.title('Chemicals Reported Per Year')
plt.xlabel('Year')
plt.ylabel('Number of New Chemicals')
plt.show()

# %% [markdown]
# ## 2.10 Top Companies with Most Reported Chemicals

# %%
top_companies = newc_df['CompanyName'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_companies.values, y=top_companies.index, palette='viridis')

plt.title('Top 10 Companies by Number of Reported Chemicals')
plt.xlabel('Number of Reported Chemicals')
plt.ylabel('Company Name')
plt.tight_layout()
plt.show()
plt.savefig('top_companies_rep_ch.png');
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15752\2003656635.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_companies.values, y=top_companies.index, palette='viridis')

# %% [markdown]
# ###

# %% [markdown]
# ## 2.11 Chemical Was Removed After Report

# %%
removed_after_report = (
    (newc_df['ChemicalDateRemoved'].notna()) &
    (
        (newc_df['ChemicalDateRemoved'] > newc_df['InitialDateReported']) |
        (newc_df['ChemicalDateRemoved'] > newc_df['MostRecentDateReported'])
    )
)

count_removed_after_report = removed_after_report.sum()

print("Number of chemicals removed after being reported:", count_removed_after_report)
# Out:
# Number of chemicals removed after being reported: 1861

# %% [markdown]
# ## 2.12 Chemical Was Removed or Product Discontinued

# %%
removed_or_discontinued = (
    newc_df['ChemicalDateRemoved'].notna() |
    newc_df['DiscontinuedDate'].notna()
)

count_removed_or_discontinued = removed_or_discontinued.sum()
print("Number of chemicals removed or products discontinued:", count_removed_or_discontinued)
# Out:
# Number of chemicals removed or products discontinued: 15485

# %% [markdown]
# ### 2.12.1 The percentage of chemicals removed or discountinued over the total

# %%
perce=count_removed_or_discontinued/newc_df.shape[0]*100
print(perce,"%")
# Out:
# 13.508090897195446 %

# %%
perce = count_removed_or_discontinued / newc_df.shape[0] * 100

# Values for the chart
labels = ['Removed or Discontinued', 'Still Active']
sizes = [perce, 100 - perce]
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90, wedgeprops={'width':0.4})
plt.title('Chemical Product Removed or Discontinued Rate')
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
newc_df.head()
# Out:
#    CDPHId                                       ProductName  CompanyId  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES          4
# 1       3                        Glover's Medicated Shampoo        338
# 2       3                        Glover's Medicated Shampoo        338
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �          4
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �          4
#
#            CompanyName BrandName  PrimaryCategoryId  \
# 0         New Avon LLC      AVON                 44
# 1  J. Strickland & Co.  Glover's                 18
# 2  J. Strickland & Co.  Glover's                 18
# 3         New Avon LLC      AVON                 44
# 4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  \
# 0    Makeup Products (non-permanent)             53
# 1  Hair Care Products (non-coloring)             25
# 2  Hair Care Products (non-coloring)             25
# 3    Makeup Products (non-permanent)             46
# 4    Makeup Products (non-permanent)             52
#
#                                   SubCategory   CasNumber  \
# 0  Lip Color - Lipsticks, Liners, and Pencils  13463-67-7
# 1    Hair Shampoos (making a cosmetic claim)   65996-92-1
# 2    Hair Shampoos (making a cosmetic claim)     140-67-0
# 3                    Eyeliner/Eyebrow Pencils  13463-67-7
# 4                             Lip Gloss/Shine  13463-67-7
#
#              ChemicalName InitialDateReported MostRecentDateReported  \
# 0        Titanium dioxide          2009-06-17             2013-08-28
# 1  Distillates (coal tar)          2009-07-01             2009-07-01
# 2               Estragole          2009-07-01             2009-07-01
# 3        Titanium dioxide          2009-07-09             2013-08-28
# 4        Titanium dioxide          2009-07-09             2013-08-28
#
#   DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved  \
# 0       2011-02-01        2009-07-09        2009-07-09                 NaT
# 1              NaT        2009-07-01        2009-07-01                 NaT
# 2              NaT        2009-07-02        2009-07-02                 NaT
# 3              NaT        2009-07-09        2009-07-09                 NaT
# 4       2011-02-01        2009-07-09        2009-07-09                 NaT
#
#    ChemicalCount  YearReported
# 0              1          2009
# 1              2          2009
# 2              2          2009
# 3              1          2009
# 4              1          2009

# %% [markdown]
# ## 2.13 Cosmetics products by category

# %%
category_counts = newc_df["PrimaryCategory"].value_counts()

total = category_counts.sum()
category_percent = category_counts / total

main_categories = category_percent[category_percent >= 0.04]
other_categories = category_percent[category_percent < 0.04]

final_categories = main_categories.copy()
final_categories['Others'] = other_categories.sum()

plt.figure(figsize=(8, 6))
plt.pie(final_categories, labels=final_categories.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Cosmetic Products by Category')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.14 Max Number of chemicals in one product

# %%
max_c = newc_df['ChemicalCount'].max()
print("Maximum number of chemicals in a single product:", max_c)

highc = (newc_df['ChemicalCount'] >= 20).sum()
print(f"Products with 20+ chemicals: {highc}")
# Out:
# Maximum number of chemicals in a single product: 9
# Products with 20+ chemicals: 0
